# %%
# Load Dataframe
import pandas as pd
DATA_PATH = "data/raw/HIV_train.csv"
data = pd.read_csv(DATA_PATH)
data.head()
# Out:
#    index                                             smiles activity  \
# 0   3999                  CC1c2nc(N)nc(N)c2CN1C(=O)c1ccccc1       CI
# 1   4000              Cc1nc(N)c2c(n1)C(C)N(C(=O)c1ccccc1)C2       CI
# 2   4001                              NC(=S)NN=Cc1ccc(O)cn1       CI
# 3   4002  COC1C(OC(=O)c2ccc(C)[nH]2)C(O)C(Oc2ccc3c(O)c(N...       CM
# 4   4003                      O=C1C=C2C=CC3CC2(O1)C1CCCCN31       CI
#
#    HIV_active
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
print(data.shape)
print(data["HIV_active"].value_counts())
# Out:
# (37128, 4)
# HIV_active
# 0    35850
# 1     1278
# Name: count, dtype: int64

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

# %%
sample_smiles  = data["smiles"][4:20].values
sample_mols = [Chem.MolFromSmiles(smiles) for smiles in sample_smiles]
grid = Draw.MolsToGridImage(sample_mols, molsPerRow = 4, subImgSize = (800,800))
grid

# %%
from torch_geometric.data import Dataset, Data
import numpy as np
import os
from rdkit.Chem import rdmolops
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from torch_geometric.data import Dataset
#       2 import numpy as np
#       3 import os
#
# File c:\Users\Legion\Documents\GitHub\Graph-Neural-Networks-Pytorch\peepo\Lib\site-packages\torch_geometric\__init__.py:17
#      14 from .debug import is_debug_enabled, debug, set_debug
#      16 import torch_geometric.utils
# ---> 17 import torch_geometric.data
#      18 import torch_geometric.sampler
#      19 import torch_geometric.loader
#
# File c:\Users\Legion\Documents\GitHub\Graph-Neural-Networks-Pytorch\peepo\Lib\site-packages\torch_geometric\data\__init__.py:76
#      72 from torch_geometric.loader import DenseDataLoader
#      74 # Serialization ###############################################################
# ---> 76 if torch_geometric.typing.WITH_PT24:
# ...
